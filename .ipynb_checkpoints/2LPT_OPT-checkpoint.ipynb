# %%
include("jl/init_default.jl");
# Out:
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition info(Any...) in module Base at util.jl:334 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: Method definition warn(Any...) in module Base at util.jl:364 overwritten in module Logging at /home/skariel/.julia/v0.4/Logging/src/Logging.jl:61.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: module Winston should explicitly import * from Base
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# 22-פבר 06:52:43:INFO:root:N=74293025 min(m)=46.538624 max(m)=959026.75
# 22-פבר 06:52:44:INFO:root:rescaling masses
# 22-פבר 06:52:44:INFO:root:N=74293025 min(m)=50.036606 max(m)=1.0311101e6

# %%
include("jl/all.jl")
pop_posv()
# Out:
# WARNING: redefining constant RAW_DS_FN

# %%
opos_i = SharedArray(Float32, size(pos));

# %%
copy_into!(opos_i, pos);

# %%
optimize_2lpt_vs_pushed_pos!(rho, opos_i, pos, m, 0.001, 1.0, 0.21, 200);
# Out:
# 22-פבר 06:52:54:INFO:root:opt2lpt start a_from=0.001 a_to=1.0 end_meandx=200 fracmov=0.21
# 22-פבר 06:52:54:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 06:53:15:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 06:53:22:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 06:53:29:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 06:53:56:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 06:54:03:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 06:54:10:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 06:54:19:INFO:root:sim2lpt end
# 22-פבר 06:54:20:INFO:root:opt2lpt step=1 mdx=7206.927
# 22-פבר 06:54:24:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 06:54:45:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 06:54:52:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 06:54:59:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 06:55:25:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 06:55:33:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 06:55:40:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 06:55:50:INFO:root:sim2lpt end
# 22-פבר 06:55:50:INFO:root:opt2lpt step=2 mdx=3451.5342
# 22-פבר 06:55:54:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 06:56:14:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 06:56:21:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 06:56:28:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 06:56:54:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 06:57:01:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 06:57:08:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 06:57:17:INFO:root:sim2lpt end
# 22-פבר 06:57:18:INFO:root:opt2lpt step=3 mdx=2002.589
# 22-פבר 06:57:21:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 06:57:41:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 06:57:48:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 06:57:55:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 06:58:21:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 06:58:28:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 06:58:35:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 06:58:44:INFO:root:sim2lpt end
# 22-פבר 06:58:45:INFO:root:opt2lpt step=4 mdx=1220.7971
# 22-פבר 06:58:48:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 06:59:08:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 06:59:15:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 06:59:22:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 06:59:48:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 06:59:55:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 07:00:02:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 07:00:12:INFO:root:sim2lpt end
# 22-פבר 07:00:12:INFO:root:opt2lpt step=5 mdx=771.58105
# 22-פבר 07:00:16:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 07:00:36:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 07:00:43:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 07:00:50:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 07:01:16:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 07:01:23:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 07:01:30:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 07:01:40:INFO:root:sim2lpt end
# 22-פבר 07:01:40:INFO:root:opt2lpt step=6 mdx=505.6329
# 22-פבר 07:01:44:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 07:02:05:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 07:02:12:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 07:02:19:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 07:02:45:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 07:02:52:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 07:02:59:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 07:03:08:INFO:root:sim2lpt end
# 22-פבר 07:03:09:INFO:root:opt2lpt step=7 mdx=344.15527
# 22-פבר 07:03:12:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 07:03:33:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 07:03:39:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 07:03:46:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 07:04:12:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 07:04:19:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 07:04:26:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 07:04:36:INFO:root:sim2lpt end
# 22-פבר 07:04:36:INFO:root:opt2lpt step=8 mdx=243.59534
# 22-פבר 07:04:40:INFO:root:sim2lpt start from a=0.001 to a=1.0
# 22-פבר 07:05:01:INFO:root:sim2lpt 1st order dim 1
# 22-פבר 07:05:08:INFO:root:sim2lpt 1st order dim 2
# 22-פבר 07:05:15:INFO:root:sim2lpt 1st order dim 3
# 22-פבר 07:05:41:INFO:root:sim2lpt 2nd order dim 1
# 22-פבר 07:05:49:INFO:root:sim2lpt 2nd order dim 2
# 22-פבר 07:05:57:INFO:root:sim2lpt 2nd order dim 3
# 22-פבר 07:06:07:INFO:root:sim2lpt end
# 22-פבר 07:06:07:INFO:root:opt2lpt step=9 mdx=179.31268
# 22-פבר 07:06:07:INFO:root:opt2lpt end

# %%
mean_std_dx_vs_pushed_pos(opos_i)
# Out:
# (3107.6895f0,2399.8928f0)

# %%
kd = get_kd(pos);

# %%
to_rho!(opos_i,m, rho);
rho_to_1st_order_vel_pot!(rho);
get_1st_order_comoving_vel!(c, 1.0, 1, pos, rho);
_vx1 = real(c)
first_order_vel_pot_to_sencond_order!(rho);
get_2nd_order_comoving_vel!(c, 1.0, 1, pos, rho);

_vx2 = real(c);

# %%
get_slope_std_smoothed(kd, _vx1-0.5*_vx2, vx, pos, 10000.0, 100000)
# Out:
# (1.4606588979577833,84.791923216313)

# %%
to_rho!(opos_i,m, rho);

# %%
imrho = real(rho[:,:,254]) + real(rho[:,:,255]) + real(rho[:,:,256])
Winston.set_default_plot_size(700,700)
imagesc(log10(1e-8+imrho))
# Out:
# Winston.FramedPlot(...)

# %%
to_delta!(rho);

# %%
corr = get_correlation(rho);

# %%
pop_posv()
to_rho!(pos,m, rho);
to_delta!(rho)
corr_org = get_correlation(rho);

# %%
semilogy(xl/1000, corr*1.5)
hold(true)
semilogy(xl/1000, corr_org, "red")
hold(false)
xlim(50,200)
grid(true)
xlabel("Mpc/h")
ylabel("\\xi")
# Out:
# Winston.FramedPlot(...)
