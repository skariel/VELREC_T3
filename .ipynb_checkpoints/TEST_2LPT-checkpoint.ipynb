# %%
include("jl/init_default.jl");
# Out:
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: module Winston should explicitly import * from Base
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: requiring "Dates" in module "Winston" did not define a corresponding module.
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# WARNING: module Winston should explicitly import * from Base
# (length(m),minimum(m),maximum(m)) = (74293025,46.538624f0,959026.75f0)
# (length(m),minimum(m),maximum(m)) = (74293025,50.036606f0,1.0311101f6)

# %%
include("jl/all.jl")
# Out:
# WARNING: redefining constant RAW_DS_FN
# load_raw_halos1600 (generic function with 3 methods)

# %%
to_rho!(pos,m, rho);

# %%
imrho = real(rho[:,:,254]) + real(rho[:,:,255]) + real(rho[:,:,256])
Winston.set_default_plot_size(700,700)
imagesc(log10(1e-8+imrho))
# Out:
# Winston.FramedPlot(...)

# %%
to_delta!(rho);

# %%
corr = get_correlation(rho);

# %%
semilogy(xl/1000, corr/512^3)
xlim(50,200)
grid(true)
xlabel("Mpc/h")
ylabel("\\xi")
# Out:
# Winston.FramedPlot(...)

# %%
to_g_fft!(rho);
in_place_multiply!(rho, -1.0/4π);

# %%
@time from_cic_dim2!(c,pos,rho,1);
# Out:
#   1.717116 seconds (150.01 k allocations: 107.804 MB, 0.43% gc time)

# %%
_lvx = -D(1.0)*F(1.0)*Ha(1.0)*real(c);

# %%
std(_lvx)
# Out:
# 259.2804f0

# %%
kd = get_kd(pos);

# %%
get_slope_std_smoothed(_lvx, vx, pos, 5000.0, 100000)
# Out:
# (1.0270093418724702,110.6947911590178)

# %%
xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
@time to_tlpt_delta!(rho);
# Out:
#   6.292556 seconds (962.68 k allocations: 1.038 GB, 0.22% gc time)

# %%
to_g_fft!(rho);
in_place_multiply!(rho, -1.0/4π);

# %%
@time from_cic_dim2!(c,pos,rho,1);

# %%
_lvx2 = D2(1.0)*F2(1.0)*Ha(1.0)*real(c);

# %%
std(_lvx2)

# %%
kd = get_kd(pos);

# %%
get_slope_std_smoothed(_lvx-_lvx2/4, vx, pos, 10000.0, 100000)
